# %% [markdown]
# ## Experiment tracking using MlFlow Part 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR
import pickle
# %matplotlib inline
# dataset source : https://www.kaggle.com/datasets/ujjwalwadhwa/cars24com-used-cars-dataset

# %%
df = pd.read_csv("cars_24_combined.csv", index_col=None).drop(columns=['Unnamed: 0'])
df.head()
# Out:
#                Car Name    Year  Distance  Owner    Fuel Location      Drive
# 0       Maruti S PRESSO  2022.0      3878      1  PETROL    HR-98     Manual  \
# 1         Hyundai Xcent  2018.0     32041      1  PETROL    TN-22     Manual
# 2           Tata Safari  2021.0     96339      1  DIESEL    TS-08  Automatic
# 3  Maruti Vitara Brezza  2019.0     51718      1  DIESEL    WB-24     Manual
# 4            Tata Tiago  2021.0     19811      1  PETROL    HR-51     Manual
#
#         Type    Price
# 0  HatchBack   514000
# 1      Sedan   674000
# 2        SUV  1952000
# 3        SUV   690000
# 4  HatchBack   526000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8015 entries, 0 to 8014
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Car Name  8014 non-null   object
#  1   Year      8014 non-null   float64
#  2   Distance  8015 non-null   int64
#  3   Owner     8015 non-null   int64
#  4   Fuel      8015 non-null   object
#  5   Location  7802 non-null   object
#  6   Drive     8015 non-null   object
#  7   Type      8015 non-null   object
#  8   Price     8015 non-null   int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 563.7+ KB

# %% [markdown]
# #### Checking for Null values

# %%
df.isna().sum()
# Out:
# Car Name      1
# Year          1
# Distance      0
# Owner         0
# Fuel          0
# Location    213
# Drive         0
# Type          0
# Price         0
# dtype: int64

# %% [markdown]
# Location is an important factor in determining the price as the price of the same vehicle varies with the state it was bought in (owing to taxation rules) and therefore imputing the missing values using mode or other similar imputation methods won't be a good ideas as it might distort the patterns that the ML model will learn. So, we will drop the null item rows.

# %%
print(df.shape)
df.dropna(inplace=True)
print(f'Shape of dataset after dropping the null item rows {df.shape}')
# Out:
# (8015, 9)
# Shape of dataset after dropping the null item rows (7801, 9)

# %% [markdown]
# ### Data Cleaning and Featurization

# %% [markdown]
# #### Clean and featurize 'Location' column

# %%
len(dict(df.Location.value_counts()))
# Out:
# 436

# %% [markdown]
# As we can see the Location feature is a categorical feature but still has too many different/unique values. One way to resolve this is to consider only state rather than the district of the vehicle. As the price of the vehicle is almost the same across different cities in the state, it is okay if we drop the last two digits (indicating district) and consider only the first two letter (indicating the state).

# %%
df.Location = df.Location.str.split('-').apply(lambda x : x[0])

# %%
len(dict(df.Location.value_counts()))
# Out:
# 17

# %% [markdown]
# Now, there are only 17 different values in this categorical column and can be easily label encoded.

# %%
# For the price column, we see that the prices are in multiple of 1000. So, let's divide them all by thousand and keep it 
# in terms of 1000
df['Price'] = df.Price.apply(lambda x : x/1000)

# %%
df.columns
# Out:
# Index(['Car Name', 'Year', 'Distance', 'Owner', 'Fuel', 'Location', 'Drive',
#        'Type', 'Price'],
#       dtype='object')

# %% [markdown]
# ## Vectorization

# %%
categorical_features = ['Car Name', 'Fuel', 'Location', 'Drive', 'Type']
target_feature = 'Price'

X = df.drop(columns='Price')
y = df['Price'].values

oe = OrdinalEncoder()
oe.fit(X=X[categorical_features])
X[categorical_features] = oe.transform( X[categorical_features] )

scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
X_train, X_ref, y_train, y_ref = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

# %%
with open('data/dataset.bin', 'wb') as f_out :
    pickle.dump( (X, y), f_out)

# %%
with open('data/train.bin', 'wb') as f_out :
    pickle.dump( (X_train, y_train), f_out)

with open('data/test.bin', 'wb' ) as f_out : 
    pickle.dump( (X_test, y_test), f_out) 

with open('data/reference_data.bin', 'wb' ) as f_out :
    pickle.dump( (X_ref, y_ref), f_out)

#with open('preprocess/preprocess.bin', 'wb') as f_out : 
#    pickle.dump( (oe, scaler), f_out)

# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("first_experiment")
# Out:
# 2023/07/20 03:37:53 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2023/07/20 03:37:53 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2023/07/20 03:37:53 INFO mlflow.tracking.fluent: Experiment with name 'first_experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///D:/0 mlopscamp/mlruns/1', creation_time=1689838673556, experiment_id='1', last_update_time=1689838673556, lifecycle_stage='active', name='first_experiment', tags={}>

# %% [markdown]
# ### SGDRegressor

# %%
def objective_linReg(search_space):
    with mlflow.start_run():
        mlflow.set_tag("developer", "rishikesh")
        
        linReg = SGDRegressor(**search_space, random_state=101)
        linReg.fit(X_train, y_train)

        pred_train = linReg.predict(X_train)
        pred_test = linReg.predict(X_test)

        train_error = mean_squared_error(y_train, pred_train)
        test_error = mean_squared_error(y_test, pred_test)
        
        mlflow.log_metric("train_mse", train_error)
        mlflow.log_metric("test_mse", test_error)
        mlflow.log_artifact("preprocess/preprocess.bin", artifact_path="preprocess")
        mlflow.sklearn.log_model(linReg, artifact_path = "models")

    return { 'loss' : train_error, 'status': STATUS_OK }
    
search_space = {
    'penalty' : hp.choice( "penalty", ['l2', 'l1', 'elasticnet']),
    'alpha' : hp.loguniform('alpha', -5, -1),
}

best_params = fmin(
    fn = objective_linReg,
    space = search_space,
    algo = tpe.suggest,
    max_evals = 25
)
# Out:
# 100%|█████████████████████████████████████████████████| 25/25 [01:26<00:00,  3.47s/trial, best loss: 36871.32817847238]

# %%
best_params
# Out:
# {'alpha': 0.0685546505156344, 'penalty': 2}

# %%
# with open('models/linReg.bin', 'wb') as f_out : 
#    pickle.dump( (oe, scaler, linReg), f_out)

# %% [markdown]
# ### XGBoost

# %%
xg_train = xgb.DMatrix(X_train, label=y_train)
xg_test = xgb.DMatrix(X_test, label=y_test)

mlflow.xgboost.autolog()

def objective_xgboost(params):
    with mlflow.start_run():
        booster = xgb.train(
            params=params,
            dtrain=xg_train,
            num_boost_round=100,
            evals=[(xg_test, 'testing')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(xg_test)
        mse = mean_squared_error(y_test, y_pred, squared=False)
        mlflow.log_artifact("preprocess/preprocess.bin", artifact_path="preprocess")
    return {'loss': mse, 'status': STATUS_OK}

search_space_1 = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 50, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:squarederror',
    'seed': 42
}

best_result = fmin(
    fn=objective_xgboost,
    space=search_space_1,
    algo=tpe.suggest,
    max_evals=25
)
# Out:
# 2023/07/20 04:00:36 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of xgboost. If you encounter errors during autologging, try upgrading / downgrading xgboost to a supported version, or try upgrading MLflow.
# [04:00:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	testing-rmse:227.43897
# [1]	testing-rmse:132.55855
# [2]	testing-rmse:117.93487
# [3]	testing-rmse:120.31805
# [4]	testing-rmse:120.04165
# [5]	testing-rmse:121.80466
# [6]	testing-rmse:122.39184
# [7]	testing-rmse:122.58770
# [8]	testing-rmse:123.74518
# [9]	testing-rmse:123.78737
# [10]	testing-rmse:123.63273
# [11]	testing-rmse:124.01955
# [12]	testing-rmse:123.59525
# [13]	testing-rmse:123.69857
# [14]	testing-rmse:123.75679
# [15]	testing-rmse:123.60569
# [16]	testing-rmse:123.55336
# [17]	testing-rmse:123.29247
# [18]	testing-rmse:123.42258
# [19]	testing-rmse:123.52616
# [20]	testing-rmse:123.44045
# [21]	testing-rmse:123.44036
# [22]	testing-rmse:123.56231
# [23]	testing-rmse:123.52738
# [24]	testing-rmse:123.47600
# [25]	testing-rmse:123.52907
# [26]	testing-rmse:123.52435
# [27]	testing-rmse:123.55578
# [28]	testing-rmse:123.58959
# [29]	testing-rmse:123.55312
# [30]	testing-rmse:123.52179
# [31]	testing-rmse:123.52847
# [32]	testing-rmse:123.53377
# [33]	testing-rmse:123.55167
# [34]	testing-rmse:123.56118
# [35]	testing-rmse:123.55924
# [36]	testing-rmse:123.54535
# [37]	testing-rmse:123.54932
# [38]	testing-rmse:123.55400
# [39]	testing-rmse:123.55256
# [40]	testing-rmse:123.56285
# [41]	testing-rmse:123.56999
# [42]	testing-rmse:123.57592
# [43]	testing-rmse:123.57619
# [44]	testing-rmse:123.57969
# [45]	testing-rmse:123.58281
# [46]	testing-rmse:123.57947
# [47]	testing-rmse:123.58193
# [48]	testing-rmse:123.58640
# [49]	testing-rmse:123.59039
# [50]	testing-rmse:123.59375
# [51]	testing-rmse:123.59222
# [52]	testing-rmse:123.59100
# [04:00:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	testing-rmse:149.19470
# [1]	testing-rmse:132.50636
# [2]	testing-rmse:129.25622
# [3]	testing-rmse:121.93405
# [4]	testing-rmse:118.76318
# [5]	testing-rmse:116.38625
# [6]	testing-rmse:116.64232
# [7]	testing-rmse:116.40470
# [8]	testing-rmse:116.13721
# [9]	testing-rmse:118.01479
# [10]	testing-rmse:118.56176
# [11]	testing-rmse:118.61476
# [12]	testing-rmse:118.95464
# [13]	testing-rmse:119.04586
# [14]	testing-rmse:119.21656
# [15]	testing-rmse:118.46714
# [16]	testing-rmse:118.01149
# [17]	testing-rmse:119.51019
# [18]	testing-rmse:120.23491
# [19]	testing-rmse:121.39043
# [20]	testing-rmse:120.20831
# [21]	testing-rmse:120.45965
# [22]	testing-rmse:121.03564
# [23]	testing-rmse:121.44799
# [24]	testing-rmse:121.90465
# [25]	testing-rmse:122.13744
# [26]	testing-rmse:122.61621
# [27]	testing-rmse:123.15641
# [28]	testing-rmse:122.89667
# [29]	testing-rmse:123.03785
# [30]	testing-rmse:123.09880
# [31]	testing-rmse:123.91123
# [32]	testing-rmse:124.49442
# [33]	testing-rmse:124.33451
# [34]	testing-rmse:125.11385
# [35]	testing-rmse:126.03696
# [36]	testing-rmse:125.10937
# [37]	testing-rmse:125.34339
# [38]	testing-rmse:126.06502
# [39]	testing-rmse:127.17712
# [40]	testing-rmse:126.98503
# [41]	testing-rmse:127.07093
# [42]	testing-rmse:127.01035
# [43]	testing-rmse:127.50190
# [44]	testing-rmse:127.71739
# [45]	testing-rmse:127.89751
# [46]	testing-rmse:128.85680
# [47]	testing-rmse:128.77510
# [48]	testing-rmse:128.16708
# [49]	testing-rmse:128.07017
# [50]	testing-rmse:127.58119
# [51]	testing-rmse:127.60515
# [52]	testing-rmse:127.88166
# [53]	testing-rmse:128.52098
# [54]	testing-rmse:128.86141
# [55]	testing-rmse:128.69694
# [56]	testing-rmse:129.10372
# [57]	testing-rmse:129.40624
# [04:00:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	testing-rmse:534.80731
# [1]	testing-rmse:458.35041
# [2]	testing-rmse:393.10112
# [3]	testing-rmse:338.21154
# [4]	testing-rmse:292.94186
# [5]	testing-rmse:256.04194
# [6]	testing-rmse:225.64120
# [7]	testing-rmse:200.54913
# [8]	testing-rmse:180.00924
# [9]	testing-rmse:163.32512
# [10]	testing-rmse:150.55465
# [11]	testing-rmse:140.42617
# [12]	testing-rmse:132.61261
# [13]	testing-rmse:126.55335
# [14]	testing-rmse:121.90816
# [15]	testing-rmse:118.78162
# [16]	testing-rmse:116.53618
# [17]	testing-rmse:114.82532
# [18]	testing-rmse:113.68233
# [19]	testing-rmse:112.89515
# [20]	testing-rmse:112.11991
# [21]	testing-rmse:111.34286
# [22]	testing-rmse:111.04828
# [23]	testing-rmse:110.50853
# [24]	testing-rmse:110.43421
# [25]	testing-rmse:110.13009
# [26]	testing-rmse:110.25088
# [27]	testing-rmse:110.05623
# [28]	testing-rmse:109.96710
# [29]	testing-rmse:109.73357
# [30]	testing-rmse:109.66928
# [31]	testing-rmse:109.72493
# [32]	testing-rmse:109.61042
# [33]	testing-rmse:109.60447
# [34]	testing-rmse:109.67640
# [35]	testing-rmse:109.60062
# [36]	testing-rmse:109.67760
# [37]	testing-rmse:109.60425
# [38]	testing-rmse:109.50743
# [39]	testing-rmse:109.54582
# [40]	testing-rmse:109.50922
# [41]	testing-rmse:109.52758
# [42]	testing-rmse:109.51910
# [43]	testing-rmse:109.48738
# [44]	testing-rmse:109.50103
# [45]	testing-rmse:109.44847
# [46]	testing-rmse:109.48773
# [47]	testing-rmse:109.51225
# [48]	testing-rmse:109.43827
# [49]	testing-rmse:109.44679
# [50]	testing-rmse:109.44449
# [51]	testing-rmse:109.50310
# [52]	testing-rmse:109.47180
# [53]	testing-rmse:109.50946
# [54]	testing-rmse:109.49279
# [55]	testing-rmse:109.50482
# [56]	testing-rmse:109.50712
# [57]	testing-rmse:109.49137
# [58]	testing-rmse:109.51857
# [59]	testing-rmse:109.53543
# [60]	testing-rmse:109.50558
# [61]	testing-rmse:109.51002
# [62]	testing-rmse:109.51689
# [63]	testing-rmse:109.54399
# [64]	testing-rmse:109.53016
# [65]	testing-rmse:109.53108
# [66]	testing-rmse:109.59812
# [67]	testing-rmse:109.62005
# [68]	testing-rmse:109.66770
# [69]	testing-rmse:109.67983
# [70]	testing-rmse:109.71049
# [71]	testing-rmse:109.72741
# [72]	testing-rmse:109.72800
# [73]	testing-rmse:109.74366
# [74]	testing-rmse:109.74623
# [75]	testing-rmse:109.77443
# [76]	testing-rmse:109.77539
# [77]	testing-rmse:109.78198
# [78]	testing-rmse:109.78533
# [79]	testing-rmse:109.79159
# [80]	testing-rmse:109.77969
# [81]	testing-rmse:109.75782
# [82]	testing-rmse:109.76275
# [83]	testing-rmse:109.78096
# [84]	testing-rmse:109.78119
# [85]	testing-rmse:109.79195
# [86]	testing-rmse:109.77563
# [87]	testing-rmse:109.78341
# [88]	testing-rmse:109.78298
# [89]	testing-rmse:109.79731
# [90]	testing-rmse:109.79604
# [91]	testing-rmse:109.79262
# [92]	testing-rmse:109.79024
# [93]	testing-rmse:109.80181
# [94]	testing-rmse:109.79730
# [95]	testing-rmse:109.79619
# [96]	testing-rmse:109.82978
# [97]	testing-rmse:109.83088
# [98]	testing-rmse:109.83584
# [04:00:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	testing-rmse:511.75560
# [1]	testing-rmse:419.78430
# [2]	testing-rmse:346.41271
# [3]	testing-rmse:288.45822
# [4]	testing-rmse:243.62426
# [5]	testing-rmse:209.17676
# [6]	testing-rmse:183.12440
# [7]	testing-rmse:164.44739
# [8]	testing-rmse:151.14188
# [9]	testing-rmse:142.10184
# [10]	testing-rmse:136.10893
# [11]	testing-rmse:132.30942
# [12]	testing-rmse:129.96578
# [13]	testing-rmse:128.55828
# [14]	testing-rmse:127.75693
# [15]	testing-rmse:127.29943
# [16]	testing-rmse:127.02649
# [17]	testing-rmse:126.94914
# [18]	testing-rmse:126.89221
# [19]	testing-rmse:126.89261
# [20]	testing-rmse:126.91222
# [21]	testing-rmse:126.96988
# [22]	testing-rmse:127.01499
# [23]	testing-rmse:127.06162
# [24]	testing-rmse:127.11830
# [25]	testing-rmse:127.16650
# [26]	testing-rmse:127.20227
# [27]	testing-rmse:127.23423
# [28]	testing-rmse:127.26464
# [29]	testing-rmse:127.28414
# [30]	testing-rmse:127.29290
# [31]	testing-rmse:127.30457
# [32]	testing-rmse:127.31363
# [33]	testing-rmse:127.31339
# [34]	testing-rmse:127.31839
# [35]	testing-rmse:127.32008
# [36]	testing-rmse:127.32666
# [37]	testing-rmse:127.33371
# [38]	testing-rmse:127.33630
# [39]	testing-rmse:127.33963
# [40]	testing-rmse:127.34133
# [41]	testing-rmse:127.34166
# [42]	testing-rmse:127.34426
# [43]	testing-rmse:127.34640
# [44]	testing-rmse:127.34874
# [45]	testing-rmse:127.35157
# [46]	testing-rmse:127.35270
# [47]	testing-rmse:127.35355
# [48]	testing-rmse:127.35466
# [49]	testing-rmse:127.35601
# [50]	testing-rmse:127.35651
# [51]	testing-rmse:127.35670
# [52]	testing-rmse:127.35720
# [53]	testing-rmse:127.35734
# [54]	testing-rmse:127.35711
# [55]	testing-rmse:127.35748
# [56]	testing-rmse:127.35800
# [57]	testing-rmse:127.35810
# [58]	testing-rmse:127.35825
# [59]	testing-rmse:127.35869
# [60]	testing-rmse:127.35864
# [61]	testing-rmse:127.35875
# [62]	testing-rmse:127.35854
# [63]	testing-rmse:127.35855
# [64]	testing-rmse:127.35889
# [65]	testing-rmse:127.35902
# [66]	testing-rmse:127.35903
# [67]	testing-rmse:127.35916
# [04:01:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	testing-rmse:590.90189
# [1]	testing-rmse:557.58569
# [2]	testing-rmse:526.25568
# [3]	testing-rmse:497.07208
# [4]	testing-rmse:469.37521
# [5]	testing-rmse:443.51779
# [6]	testing-rmse:419.30262
# [7]	testing-rmse:396.58686
# [8]	testing-rmse:375.34342
# [9]	testing-rmse:355.63143
# [10]	testing-rmse:336.96434
# [11]	testing-rmse:319.61562
# [12]	testing-rmse:303.52560
# [13]	testing-rmse:288.33355
# [14]	testing-rmse:274.11348
# [15]	testing-rmse:261.04383
# [16]	testing-rmse:248.73528
# [17]	testing-rmse:237.02933
# [18]	testing-rmse:226.20500
# [19]	testing-rmse:216.22128
# [20]	testing-rmse:206.96707
# [21]	testing-rmse:198.52124
# [22]	testing-rmse:190.71048
# [23]	testing-rmse:183.39835
# [24]	testing-rmse:176.61377
# [25]	testing-rmse:170.68995
# [26]	testing-rmse:165.12230
# [27]	testing-rmse:159.99743
# [28]	testing-rmse:155.44500
# [29]	testing-rmse:151.14247
# [30]	testing-rmse:147.29510
# [31]	testing-rmse:143.84231
# [32]	testing-rmse:140.71913
# [33]	testing-rmse:137.81729
# [34]	testing-rmse:135.37949
# [35]	testing-rmse:133.03817
# [36]	testing-rmse:131.04514
# [37]	testing-rmse:129.21889
# [38]	testing-rmse:127.57325
# [39]	testing-rmse:126.11584
# [40]	testing-rmse:124.79088
# [41]	testing-rmse:123.57525
# [42]	testing-rmse:122.62556
# [43]	testing-rmse:121.72233
# [44]	testing-rmse:120.86806
# [45]	testing-rmse:120.03537
# [46]	testing-rmse:119.33249
# [47]	testing-rmse:118.76729
# [48]	testing-rmse:118.25778
# [49]	testing-rmse:117.73732
# [50]	testing-rmse:117.07382
# [51]	testing-rmse:116.65431
# [52]	testing-rmse:116.37795
# [53]	testing-rmse:116.12064
# [54]	testing-rmse:115.81579
# [55]	testing-rmse:115.51529
# [56]	testing-rmse:115.30084
# [57]	testing-rmse:115.10816
# [58]	testing-rmse:114.94559
# [59]	testing-rmse:114.86816
# [60]	testing-rmse:114.76506
# [61]	testing-rmse:114.65345
# [62]	testing-rmse:114.49704
# [63]	testing-rmse:114.41839
# [64]	testing-rmse:114.24514
# [65]	testing-rmse:114.17599
# [66]	testing-rmse:114.16168
# [67]	testing-rmse:114.16784
# [68]	testing-rmse:114.04757
# [69]	testing-rmse:114.07799
# [70]	testing-rmse:114.02271
# [71]	testing-rmse:113.89982
# [72]	testing-rmse:113.95807
# [73]	testing-rmse:113.99177
# [74]	testing-rmse:114.04529
# [75]	testing-rmse:114.09350
# [76]	testing-rmse:114.08613
# [77]	testing-rmse:114.07532
# [78]	testing-rmse:114.02522
# [79]	testing-rmse:113.99711
# [80]	testing-rmse:113.98088
# [81]	testing-rmse:113.95410
# [82]	testing-rmse:113.94876
# [83]	testing-rmse:113.89767
# [84]	testing-rmse:113.90663
# [85]	testing-rmse:113.89659
# [86]	testing-rmse:113.92070
# [87]	testing-rmse:113.95772
# [88]	testing-rmse:113.99671
# [89]	testing-rmse:114.00541
# [90]	testing-rmse:113.98894
# [91]	testing-rmse:113.98604
# [92]	testing-rmse:114.01855
# [93]	testing-rmse:114.01359
# [94]	testing-rmse:114.00715
# [95]	testing-rmse:113.98137
# [96]	testing-rmse:114.00293
# [97]	testing-rmse:113.99164
# [98]	testing-rmse:113.99181
# [99]	testing-rmse:114.00990
# [04:01:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	testing-rmse:127.90700
# [1]	testing-rmse:124.85202
# [2]	testing-rmse:127.09699
# [3]	testing-rmse:127.63236
# [4]	testing-rmse:127.60719
# [5]	testing-rmse:127.61327
# [6]	testing-rmse:127.61408
# [7]	testing-rmse:127.60790
# [8]	testing-rmse:127.60683
# [9]	testing-rmse:127.60625
# [10]	testing-rmse:127.60655
# [11]	testing-rmse:127.60651
# ...
# [33]	testing-rmse:106.14848
# [34]	testing-rmse:106.12292
# [35]	testing-rmse:105.93728
# [36]	testing-rmse:105.94513
# [37]	testing-rmse:105.77808
# [38]	testing-rmse:105.75859
# [39]	testing-rmse:105.90118
# [40]	testing-rmse:105.79461
# [41]	testing-rmse:105.74940
# [42]	testing-rmse:105.64967
# [43]	testing-rmse:105.59642
# [44]	testing-rmse:105.46204
# [45]	testing-rmse:105.69441
# [46]	testing-rmse:105.67181
# [47]	testing-rmse:105.67815
# [48]	testing-rmse:105.59212
# [49]	testing-rmse:105.59575
# [50]	testing-rmse:105.59721
# [51]	testing-rmse:105.66186
# [52]	testing-rmse:105.80408
# [53]	testing-rmse:105.93378
# [54]	testing-rmse:105.80627
# [55]	testing-rmse:105.85941
# [56]	testing-rmse:106.21995
# [57]	testing-rmse:106.19319
# [58]	testing-rmse:106.34120
# [59]	testing-rmse:106.34240
# [60]	testing-rmse:106.47530
# [61]	testing-rmse:106.49597
# [62]	testing-rmse:106.40675
# [63]	testing-rmse:106.38694
# [64]	testing-rmse:106.58690
# [65]	testing-rmse:106.64021
# [66]	testing-rmse:106.66280
# [67]	testing-rmse:106.77884
# [68]	testing-rmse:106.91505
# [69]	testing-rmse:106.84771
# [70]	testing-rmse:107.00363
# [71]	testing-rmse:107.17314
# [72]	testing-rmse:107.29274
# [73]	testing-rmse:107.25221
# [74]	testing-rmse:107.26596
# [75]	testing-rmse:107.30268
# [76]	testing-rmse:107.30568
# [77]	testing-rmse:107.28597
# [78]	testing-rmse:107.52598
# [79]	testing-rmse:107.50555
# [80]	testing-rmse:107.56952
# [81]	testing-rmse:107.63113
# [82]	testing-rmse:107.66718
# [83]	testing-rmse:107.74070
# [84]	testing-rmse:107.74434
# [85]	testing-rmse:107.74282
# [86]	testing-rmse:107.66779
# [87]	testing-rmse:107.85703
# [88]	testing-rmse:107.96481
# [89]	testing-rmse:108.06494
# [90]	testing-rmse:108.10445
# [91]	testing-rmse:108.02686
# [92]	testing-rmse:107.91647
# [93]	testing-rmse:107.87706
# [04:04:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	testing-rmse:347.41707
# [1]	testing-rmse:210.46896
# [2]	testing-rmse:148.64862
# [3]	testing-rmse:122.65439
# [4]	testing-rmse:115.58004
# [5]	testing-rmse:111.69970
# [6]	testing-rmse:111.64587
# [7]	testing-rmse:110.01461
# [8]	testing-rmse:109.05669
# [9]	testing-rmse:107.79430
# [10]	testing-rmse:108.65299
# [11]	testing-rmse:109.16273
# [12]	testing-rmse:108.64369
# [13]	testing-rmse:108.98856
# [14]	testing-rmse:108.92252
# [15]	testing-rmse:108.06892
# [16]	testing-rmse:107.93697
# [17]	testing-rmse:107.82058
# [18]	testing-rmse:107.14853
# [19]	testing-rmse:107.32147
# [20]	testing-rmse:107.13231
# [21]	testing-rmse:107.77621
# [22]	testing-rmse:107.59262
# [23]	testing-rmse:107.99735
# [24]	testing-rmse:108.08596
# [25]	testing-rmse:108.29128
# [26]	testing-rmse:108.86131
# [27]	testing-rmse:109.07028
# [28]	testing-rmse:109.07535
# [29]	testing-rmse:109.12548
# [30]	testing-rmse:109.28639
# [31]	testing-rmse:109.12977
# [32]	testing-rmse:109.47640
# [33]	testing-rmse:109.27272
# [34]	testing-rmse:109.33873
# [35]	testing-rmse:109.35407
# [36]	testing-rmse:109.30369
# [37]	testing-rmse:109.44246
# [38]	testing-rmse:109.39213
# [39]	testing-rmse:109.65219
# [40]	testing-rmse:109.49934
# [41]	testing-rmse:109.84385
# [42]	testing-rmse:110.15832
# [43]	testing-rmse:110.12362
# [44]	testing-rmse:110.22157
# [45]	testing-rmse:110.21801
# [46]	testing-rmse:110.40410
# [47]	testing-rmse:110.49276
# [48]	testing-rmse:110.66392
# [49]	testing-rmse:110.43807
# [50]	testing-rmse:110.39881
# [51]	testing-rmse:110.04966
# [52]	testing-rmse:110.07499
# [53]	testing-rmse:110.26211
# [54]	testing-rmse:110.25574
# [55]	testing-rmse:110.42186
# [56]	testing-rmse:110.61645
# [57]	testing-rmse:110.45172
# [58]	testing-rmse:110.46973
# [59]	testing-rmse:110.80883
# [60]	testing-rmse:110.81105
# [61]	testing-rmse:110.90245
# [62]	testing-rmse:111.10232
# [63]	testing-rmse:111.05347
# [64]	testing-rmse:111.04746
# [65]	testing-rmse:111.18290
# [66]	testing-rmse:111.35173
# [67]	testing-rmse:111.44566
# [68]	testing-rmse:111.45148
# [69]	testing-rmse:111.31361
# 100%|█████████████████████████████████████████████████| 25/25 [03:53<00:00,  9.35s/trial, best loss: 9717.063562744794]

# %% [markdown]
# ### Ensemble models

# %%
mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor):
    with mlflow.start_run():
        mlflow.log_artifact("preprocess/preprocess.bin", artifact_path="preprocess")
        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)
        y_pred = mlmodel.predict(X_test)
        rmse = mean_squared_error(y_test, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
